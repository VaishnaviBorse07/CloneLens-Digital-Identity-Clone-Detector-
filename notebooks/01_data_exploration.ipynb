# %% [markdown]
# # CloneLens: Exploratory Data Analysis & Benchmark Inspection
#
# This notebook provides research utilities to inspect facial image datasets and text samples for synthetic artifact analysis.

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

print("CloneLens EDA Workspace Initialized.")
print(f"Data directory: {os.path.abspath('../data')}")
